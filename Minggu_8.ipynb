# %% [markdown]
# <a href="https://colab.research.google.com/github/rioferdiansyah024/PCVK_Genap_2021/blob/main/Minggu_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv2

# %%
original = cv2.imread('/content/drive/MyDrive/j.png')
img = cv2.cvtColor(original,cv2.COLOR_BGR2GRAY)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=112x150 at 0x7F575A554DD0>

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f575a4a7910>,
#  <matplotlib.image.AxesImage at 0x7f575a4142d0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f5759f05a10>,
#  <matplotlib.image.AxesImage at 0x7f5759edd350>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv2.morphologyEx(img, cv2.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f5759e68ad0>,
#  <matplotlib.image.AxesImage at 0x7f5759dc0450>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f5759da7350>,
#  <matplotlib.image.AxesImage at 0x7f5759d14790>,
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f5759c93fd0>,
#  <matplotlib.image.AxesImage at 0x7f5759c66990>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %%
element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7))
erosion_dst = cv2.erode(img, element)
opening_dst = cv2.dilate(erosion_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening_dst), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f5759bf3250>,
#  <matplotlib.image.AxesImage at 0x7f5759b3eb10>,
#  Text(0.5, 1.0, 'Citra Hasil Opening'))
