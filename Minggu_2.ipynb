# %% [markdown]
# <a href="https://colab.research.google.com/github/rioferdiansyah024/PCVK_Genap_2021/blob/main/Minggu_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**LATIHAN 1**

# %%
from google.colab import drive

# Access Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/12.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  # Konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# #**TUGAS 1**
#
#
#
# 1.   Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
# 2.   Tampilkan image dalam channel Red-Green dan Green-Blue saja
# 3.   Tampilkan image baris ke 10-100, kolom 10-100
# 4.   Tampilkan image baris ke 5-30, semua kolom, channel Green saja
# 5.   Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. Disarankan menggunakan bilangan acak
# 6.   Tampilkan image dengan posisi terbalik

# %% [markdown]
# #**JAWABAN TUGAS1**

# %% [markdown]
# ##**No.1**

# %%
img2 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10)) 
plt.imshow(img2)

# %% [markdown]
# ##**No.2**

# %%
plt.imshow(img_gray, cmap='RdYlGn'),plt.title("RedGreen")
# Out:
# (<matplotlib.image.AxesImage at 0x7efe41ec1710>, Text(0.5, 1.0, 'RedGreen'))

# %%
plt.imshow(img_gray, cmap='GnBu'),plt.title("Green-Blue")
# Out:
# (<matplotlib.image.AxesImage at 0x7efe41e1d908>, Text(0.5, 1.0, 'Green-Blue'))

# %% [markdown]
# ##**No.3**

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %% [markdown]
# ##**No.4**

# %%
plt.imshow(img5[5:30])

# %% [markdown]
# ##**No.5**

# %%
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(5):
  startp = random.randint(0,500)
  endp = random.randint(0,1000)

  c1 = random.randint(0,200)
  c2 = random.randint(0,255)
  c3 = random.randint(0,800)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  color = (c1, c2, c3) 
    
  thickness = 2
    
  img6 = cv.rectangle(img6, start_point, end_point, color, thickness) 
    
# Displaying the image  
plt.imshow(img6)

# %% [markdown]
# ##**No.6**

# %%
img2 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img2)

# %% [markdown]
# #**LATIHAN 2**

# %%
img_gray = cv.imread('/content/12.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#Simpan file image
#

#Tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))   #Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#Perhatikan koordinat titik-titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))    # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# #**TUGAS 2**
#
#
#
# 1.   Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas
# 2.   Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers
# 3.   Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan warna font yang sesuai

# %% [markdown]
# #**JAWABAN TUGAS 2**

# %% [markdown]
# # **No.1**,**2**,**3**

# %%
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)


fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111) 

cv.rectangle(img5,pt1=(585,250),pt2=(740,690),color=(0,255,0), thickness=2)

cv.circle(img5,center=(670,290),radius=50,color=(255,0,0),thickness=2)

cv.rectangle(img5,pt1=(550,780),pt2=(780,720),color=(0,255,0), thickness=2)
cv.putText(img5, text='MALIKA',org=(560,770),fontFace=font,fontScale=2,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)

ax.imshow(img5)

# %% [markdown]
# #**PERTANYAAN**
#
# 1.   apakah ada perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib
# 2.   Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32
# 3.   Apakah kegunaan "google.colab.patches import cv2_imshow" pada potongan kode berikut
#
#
# ```
# from google.colab.patches import cv2_imshow
# from skimage import io
# ```
#
#
# 4.Apakah kegunaan "skimage import io" pada potongan kode soal no.3

# %% [markdown]
# #**JAWABAN PERTANYAAN**
#
# 1.   Ada, jika menampilkan gambar menggunakan matplotlib maka gambar akan tampil dengan ukuran dari gambar tersebut, sebaliknya jika tanpa matplotlib maka akan tampil gambar saja
# 2.   Tidak berpengaruh untuk pembuatan balck_image
# 3.   Menambahkan satu patches karena cv.imshow tidak berjalan di Google Colab
# 4.  Untuk mengimpor modul io dari skimage (skimage.io) sehingga kita dapat membaca dan menulis gambar
